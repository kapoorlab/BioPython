# %%
import sys
sys.path.append("../")
import numpy as np
from scipy.fftpack import fftfreq
import os
import glob
import cv2
import csv
from utils import show_peak, VarianceFilter, FFTStrip,FFTSpaceStrip, doubleplot, doFilterFFT,tripleplot, VelocityStrip, watershed_image_hough,DiffVelocityStrip
import pandas as pd
from tifffile import imread, imwrite
from scipy.fftpack import fft
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
from skimage.morphology import remove_small_objects, binary_erosion

from scipy.signal import find_peaks
from skimage import data, io

from skimage.filters import threshold_otsu, threshold_mean
from skimage.filters import roberts, sobel, scharr, prewitt, gaussian
try:
    from pathlib import Path
    Path().expanduser()
except (ImportError, AttributeError):
        from pathlib2 import Path

try:
        import tempfile
        tempfile.TemporaryDirectory
except (ImportError, AttributeError):
       from backports import tempfile

# %%
Kymo = '/Users/aimachine/Curvature_C2-20180824_HVJEfusion_8x16_R64umTrackID1.tif'
savedir = '/Users/aimachine/Downloads/'
Time_unit = 10
Xcalibration = 0.034

Path(savedir).mkdir(exist_ok = True)

# %%
Name = os.path.basename(os.path.splitext(Kymo)[0])
    
Kymoimage = imread(Kymo)

#Anterior Part
FFTSpaceImage, AddedVA, velocityA, BlockA = FFTSpaceStrip(Kymoimage, Xcalibration)

for i in range(0, len(BlockA)):
  plt.plot(velocityA, np.log(BlockA[i]))
plt.xlim([0,4])
plt.title('All')
plt.show()



df = pd.DataFrame(list(zip(velocityA,AddedVA)),columns =['Velocity', 'Amplitude'])
df.to_csv(savedir + Name + 'Velocity' +  '.csv', index = False)  


FFTTimeImage, AddedT, frequ, BlockT = FFTStrip(Kymoimage, Time_unit)
df = pd.DataFrame(list(zip(frequ,AddedT)),columns =['Frequency', 'Amplitude'])
df.to_csv(savedir + Name + 'Frequency' +  '.csv', index = False)  

imwrite((savedir + Name + 'FFTSpace' + '.tif' ) , np.log(FFTSpaceImage.astype('float32')))

fig, axes = plt.subplots(1, 2, figsize=(15, 6))
ax = axes.ravel()
ax[0].plot( velocityA,np.log(AddedVA), 'r')
ax[0].set_xlabel('Velocity')
ax[0].set_ylabel('Amplitude')
ax[0].set_xlim([0,4])
ax[0].set_title('FFT Space')

ax[1].plot( frequ,np.log(AddedT), 'r')
ax[1].set_title('FFT Time')
ax[1].set_xlabel('Frequency')
ax[1].set_ylabel('Amplitude')

plt.show()


imwrite((savedir + Name + 'FFTTime' + '.tif' ) , np.log(FFTTimeImage.astype('float32')))

tripleplot(Kymoimage,np.log(FFTSpaceImage), np.log(FFTTimeImage), 'Kymo', 'FFTX', 'FFFTTime')
# Out:
# /Users/aimachine/miniconda3/envs/tensorflowEnv36/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# /Users/aimachine/miniconda3/envs/tensorflowEnv36/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# /Users/aimachine/miniconda3/envs/tensorflowEnv36/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log
# /Users/aimachine/miniconda3/envs/tensorflowEnv36/lib/python3.6/site-packages/ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in log
# /Users/aimachine/miniconda3/envs/tensorflowEnv36/lib/python3.6/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in log
