# %%
import os
import sys
sys.path.append('../')
import pandas as pd
import numpy as np
import glob
from utils import MSDAnalysis

# %%
CsvDir = '/run/media/kapoorlab/a16689d2-2f12-4219-9a7a-4e5a19b8f91a/Darine/Nucleus_tracking/'
Savedir = '/run/media/kapoorlab/a16689d2-2f12-4219-9a7a-4e5a19b8f91a/Darine/Nucleus_tracking/Results/'

# %%
nbins = 10
timesmoothing = 10
time_unit = 10
displayfit = False

# %%
Raw_path = os.path.join(CsvDir, '*csv')
X = glob.glob(Raw_path)
for CsvFile in X:
   MSDAnalysis(CsvFile, Savedir, nbins, average = timesmoothing, time_unit = time_unit, displayfit = displayfit)
# Out:
# Doing MSD analysis for file:
# Experiment analysis for : Dpa_09_MSD
# DisplacementX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 61
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1398.00004
#     reduced chi-square = 199.714292
#     Akaike info crit   = 55.4021286
#     Bayesian info crit = 56.3098839
# [[Variables]]
#     amp:  306.608273 +/- 75363.6395 (24579.78%) (init = 149)
#     mu:  -0.60951342 +/- 16.6108741 (2725.27%) (init = -0.05371901)
#     std:  0.06082891 +/- 11.1665204 (18357.26%) (init = 1.037124)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -1.000
#     C(amp, mu)  = -1.000
#     C(mu, std)  =  1.000
# DisplacementY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 46
#     # data points      = 10
#     # variables        = 3
# ...
