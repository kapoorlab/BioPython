# %%
import os
sys.path.append('../')
import pandas as pd
import numpy as np
import glob
from utils import MSDAnalysis

# %%
CsvDir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/'
Savedir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/Results/'

# %%
nbins = 20

# %%
Raw_path = os.path.join(CsvDir, '*csv')
X = glob.glob(Raw_path)
for CsvFile in X:
   MSDAnalysis(CsvFile, Savedir, nbins)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-49d4ae71dcf5> in <module>
#       2 X = glob.glob(Raw_path)
#       3 for CsvFile in X:
# ----> 4    MSDAnalysis(CsvFile, Savedir, nbins)
#       5
#
# ~/Downloads/BioPython/utils.py in MSDAnalysis(CsvFile, savedir, nbins)
#     263   plt.show()
#     264   df = pd.DataFrame([[Gauss.fit_report()]],columns =['GaussFit parameters'])
# --> 265   df.to_csv(savedir + Name + 'GaussFIts' +  '.csv', index = False)
#     266   print(Gauss.fit_report())
#     267
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/Results/FileAGaussFIts.csv'
