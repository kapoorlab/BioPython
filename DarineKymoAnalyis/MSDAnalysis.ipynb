# %%
import os
import sys
sys.path.append('../')
import pandas as pd
import numpy as np
import glob
from utils import MSDAnalysis

# %%
CsvDir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/'
Savedir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/Results/'

# %%
nbins = 10
timesmoothing = 10

# %%
Raw_path = os.path.join(CsvDir, '*csv')
X = glob.glob(Raw_path)
for CsvFile in X:
   MSDAnalysis(CsvFile, Savedir, nbins, average = timesmoothing)
# Out:
# FileA
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1499.17404
#     reduced chi-square = 214.167720
#     Akaike info crit   = 56.1008450
#     Bayesian info crit = 57.0086003
# [[Variables]]
#     amp:  181.754075 +/- 14.6516746 (8.06%) (init = 182)
#     mu:  -0.71659013 +/- 0.09329257 (13.02%) (init = 0.3824363)
#     std:  0.81111720 +/- 0.14456412 (17.82%) (init = 1.66736)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.306
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 4251.00001
#     reduced chi-square = 607.285715
#     Akaike info crit   = 66.5232444
#     Bayesian info crit = 67.4309996
# [[Variables]]
#     amp:  228.177317 +/- 6718.18742 (2944.28%) (init = 228)
#     mu:  -0.00406915 +/- 76.8041917 (1887473.40%) (init = 0.3456091)
#     std:  0.02129908 +/- 7.26923439 (34129.33%) (init = 0.9518667)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(amp, std) = -0.357
#     C(mu, std)  =  0.349
# FileB
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 2027.35249
#     reduced chi-square = 289.621784
#     Akaike info crit   = 59.1190093
#     Bayesian info crit = 60.0267646
# [[Variables]]
#     amp:  100.162165 +/- 17.2668123 (17.24%) (init = 100)
#     mu:  -0.75143331 +/- 0.20421982 (27.18%) (init = 0.2469636)
#     std:  0.76130544 +/- 0.30034865 (39.45%) (init = 2.272824)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.306
#     C(mu, std)  =  0.185
#     C(amp, mu)  = -0.135
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 41
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 761.254410
#     reduced chi-square = 108.750630
#     Akaike info crit   = 49.3238252
#     Bayesian info crit = 50.2315805
# [[Variables]]
#     amp:  106.983164 +/- 10.5950935 (9.90%) (init = 108)
#     mu:   0.11146836 +/- 0.09266306 (83.13%) (init = 0.4291498)
#     std:  1.03983267 +/- 0.22474447 (21.61%) (init = 1.554034)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.498
#     C(mu, std)  = -0.129
# FileC
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 161.379535
#     reduced chi-square = 23.0542193
#     Akaike info crit   = 33.8117386
#     Bayesian info crit = 34.7194939
# [[Variables]]
#     amp:  210.172624 +/- 4.94843566 (2.35%) (init = 208)
#     mu:  -0.96064134 +/- 0.03566240 (3.71%) (init = 0.09722222)
#     std:  2.11621255 +/- 0.10845330 (5.12%) (init = 2.134113)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.439
#     C(mu, std)  =  0.221
#     C(amp, mu)  = -0.152
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1307.00029
#     reduced chi-square = 186.714328
#     Akaike info crit   = 54.7290485
#     Bayesian info crit = 55.6368037
# [[Variables]]
#     amp:  507.476580 +/- 44898.5807 (8847.42%) (init = 262)
#     mu:   0.03722630 +/- 7.80505232 (20966.50%) (init = 0.07777778)
#     std:  0.08512265 +/- 5.89131339 (6920.97%) (init = 0.7706819)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -1.000
#     C(amp, mu)  =  1.000
#     C(mu, std)  = -1.000
# Dpa_05_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 2027.35249
#     reduced chi-square = 289.621784
#     Akaike info crit   = 59.1190093
#     Bayesian info crit = 60.0267646
# [[Variables]]
#     amp:  100.162165 +/- 17.2668123 (17.24%) (init = 100)
#     mu:  -0.75143331 +/- 0.20421982 (27.18%) (init = 0.2469636)
#     std:  0.76130544 +/- 0.30034865 (39.45%) (init = 2.272824)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.306
#     C(mu, std)  =  0.185
#     C(amp, mu)  = -0.135
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 41
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 761.254410
#     reduced chi-square = 108.750630
#     Akaike info crit   = 49.3238252
#     Bayesian info crit = 50.2315805
# [[Variables]]
#     amp:  106.983164 +/- 10.5950935 (9.90%) (init = 108)
#     mu:   0.11146836 +/- 0.09266306 (83.13%) (init = 0.4291498)
#     std:  1.03983267 +/- 0.22474447 (21.61%) (init = 1.554034)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.498
#     C(mu, std)  = -0.129
# Dpa_04_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 43.9938938
#     reduced chi-square = 6.28484196
#     Akaike info crit   = 20.8146575
#     Bayesian info crit = 21.7224128
# [[Variables]]
#     amp:  295.678130 +/- 6.11901656 (2.07%) (init = 278)
#     mu:  -1.13711255 +/- 0.04325520 (3.80%) (init = 0.6091954)
#     std:  1.84337400 +/- 0.09990779 (5.42%) (init = 2.791021)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -0.889
#     C(mu, std)  =  0.845
#     C(amp, std) = -0.835
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 4138.00002
#     reduced chi-square = 591.142860
#     Akaike info crit   = 66.2538277
#     Bayesian info crit = 67.1615830
# [[Variables]]
#     amp:  230.000027 +/- 49.0269662 (21.32%) (init = 230)
#     mu:  -5.0905e-05 +/- 42.0717630 (82647426.86%) (init = 0.08045977)
#     std:  0.02245158 +/- 4.19683117 (18692.81%) (init = 0.8160515)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = -0.868
# Dpa_10_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 39
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 275.263651
#     reduced chi-square = 39.3233787
#     Akaike info crit   = 39.1514428
#     Bayesian info crit = 40.0591980
# [[Variables]]
#     amp:  187.005671 +/- 6.27420297 (3.36%) (init = 187)
#     mu:  -0.40432659 +/- 0.03720543 (9.20%) (init = 0.3111111)
#     std:  0.30240188 +/- 0.02854507 (9.44%) (init = 1.330367)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.169
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 94
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 4736.00317
#     reduced chi-square = 676.571881
#     Akaike info crit   = 67.6036375
#     Bayesian info crit = 68.5113928
# [[Variables]]
#     amp:  238.854816 +/- 10258.5542 (4294.89%) (init = 166)
#     mu:   0.15822407 +/- 6.07802391 (3841.40%) (init = -0.2925926)
#     std:  0.06879659 +/- 2.94911111 (4286.71%) (init = 0.8162361)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  =  1.000
#     C(amp, std) = -1.000
#     C(mu, std)  = -1.000
# Dpa_01_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 156.738015
#     reduced chi-square = 22.3911451
#     Akaike info crit   = 33.5199063
#     Bayesian info crit = 34.4276615
# [[Variables]]
#     amp:  58.0976166 +/- 4.78731460 (8.24%) (init = 58)
#     mu:  -0.45477683 +/- 0.09858751 (21.68%) (init = -0.1517857)
#     std:  0.75198318 +/- 0.14237398 (18.93%) (init = 1.937459)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.296
#     C(mu, std)  = -0.167
#     C(amp, mu)  =  0.122
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 57
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 251.990080
#     reduced chi-square = 35.9985829
#     Akaike info crit   = 38.2680463
#     Bayesian info crit = 39.1758016
# [[Variables]]
#     amp:  88.0161896 +/- 601.384502 (683.27%) (init = 56)
#     mu:  -0.87841130 +/- 0.98104106 (111.68%) (init = 0.4375)
#     std:  0.17142089 +/- 1.38243740 (806.46%) (init = 1.67322)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -1.000
#     C(amp, mu)  = -1.000
#     C(mu, std)  =  0.999
# Dpa_07_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 161.379535
#     reduced chi-square = 23.0542193
#     Akaike info crit   = 33.8117386
#     Bayesian info crit = 34.7194939
# [[Variables]]
#     amp:  210.172624 +/- 4.94843566 (2.35%) (init = 208)
#     mu:  -0.96064134 +/- 0.03566240 (3.71%) (init = 0.09722222)
#     std:  2.11621255 +/- 0.10845330 (5.12%) (init = 2.134113)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.439
#     C(mu, std)  =  0.221
#     C(amp, mu)  = -0.152
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1307.00029
#     reduced chi-square = 186.714328
#     Akaike info crit   = 54.7290485
#     Bayesian info crit = 55.6368037
# [[Variables]]
#     amp:  507.476580 +/- 44898.5807 (8847.42%) (init = 262)
#     mu:   0.03722630 +/- 7.80505232 (20966.50%) (init = 0.07777778)
#     std:  0.08512265 +/- 5.89131339 (6920.97%) (init = 0.7706819)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -1.000
#     C(amp, mu)  =  1.000
#     C(mu, std)  = -1.000
# Dpa_08_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 323.761073
#     reduced chi-square = 46.2515818
#     Akaike info crit   = 40.7742072
#     Bayesian info crit = 41.6819625
# [[Variables]]
#     amp:  126.985723 +/- 6.53018738 (5.14%) (init = 128)
#     mu:  -0.23072350 +/- 0.07044963 (30.53%) (init = 0.4516129)
#     std:  2.74233167 +/- 0.32195154 (11.74%) (init = 1.839332)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.567
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 118
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 3475.00104
#     reduced chi-square = 496.428720
#     Akaike info crit   = 64.5076496
#     Bayesian info crit = 65.4154049
# [[Variables]]
#     amp:  308.340641 +/- 22337.3646 (7244.38%) (init = 185)
#     mu:   0.18543803 +/- 7.30368646 (3938.61%) (init = -0.2903226)
#     std:  0.06731333 +/- 4.29136837 (6375.21%) (init = 1.018967)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  =  1.000
#     C(amp, std) = -1.000
#     C(mu, std)  = -1.000
# Dpa_09_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 61
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1398.00004
#     reduced chi-square = 199.714292
#     Akaike info crit   = 55.4021286
#     Bayesian info crit = 56.3098839
# [[Variables]]
#     amp:  306.608273 +/- 75363.6395 (24579.78%) (init = 149)
#     mu:  -0.60951342 +/- 16.6108741 (2725.27%) (init = -0.05371901)
#     std:  0.06082891 +/- 11.1665204 (18357.26%) (init = 1.037124)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -1.000
#     C(amp, mu)  = -1.000
#     C(mu, std)  =  1.000
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 46
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 2437.00001
#     reduced chi-square = 348.142859
#     Akaike info crit   = 60.9593796
#     Bayesian info crit = 61.8671349
# [[Variables]]
#     amp:  133.002782 +/- 396.422768 (298.06%) (init = 133)
#     mu:  -0.20082761 +/- 58.9000931 (29328.68%) (init = 0.4008264)
#     std:  0.03274859 +/- 7.15498734 (21848.23%) (init = 1.249991)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = -0.999
# Dpa_12_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 2150
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 321.896210
#     reduced chi-square = 45.9851729
#     Akaike info crit   = 40.7164407
#     Bayesian info crit = 41.6241960
# [[Variables]]
#     amp:  7634453.54 +/- 1.0327e+10 (135272.34%) (init = 15)
#     mu:   94.6726946 +/- 9561.04390 (10099.05%) (init = -2.169231)
#     std:  681.388915 +/- 66954.5230 (9826.18%) (init = 1.613112)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  =  1.000
#     C(mu, std)  =  1.000
#     C(amp, std) =  1.000
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 61.0000004
#     reduced chi-square = 8.71428577
#     Akaike info crit   = 24.0828878
#     Bayesian info crit = 24.9906431
# [[Variables]]
#     amp:  52.0150484 +/- 469.114884 (901.88%) (init = 52)
#     mu:  -0.10149116 +/- 23.2097072 (22868.70%) (init = 0.06153846)
#     std:  0.00768462 +/- 1.31604176 (17125.66%) (init = 0.5785106)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(amp, std) = -0.224
#     C(mu, std)  =  0.218
# Dpa_06_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 119.444069
#     reduced chi-square = 17.0634384
#     Akaike info crit   = 30.8026313
#     Bayesian info crit = 31.7103866
# [[Variables]]
#     amp:  96.8311714 +/- 4.12880140 (4.26%) (init = 97)
#     mu:  -0.39803749 +/- 0.07537741 (18.94%) (init = 1.288889)
#     std:  2.64025434 +/- 0.23838329 (9.03%) (init = 3.166647)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.382
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 674.000003
#     reduced chi-square = 96.2857147
#     Akaike info crit   = 48.1064502
#     Bayesian info crit = 49.0142055
# [[Variables]]
#     amp:  144.074806 +/- 2036.80313 (1413.71%) (init = 144)
#     mu:  -0.10200089 +/- 27.1722825 (26639.26%) (init = 0.07222222)
#     std:  0.00770872 +/- 1.54906430 (20094.97%) (init = 0.4598376)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(amp, std) = -0.295
#     C(mu, std)  =  0.288
# Dpa_03_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 59
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 133.725416
#     reduced chi-square = 19.1036309
#     Akaike info crit   = 31.9320347
#     Bayesian info crit = 32.8397900
# [[Variables]]
#     amp:  30.1801397 +/- 4.51159547 (14.95%) (init = 30)
#     mu:  -0.30311636 +/- 0.21650416 (71.43%) (init = 2.138889)
#     std:  1.28886369 +/- 0.43773256 (33.96%) (init = 3.575789)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.355
#     C(mu, std)  =  0.263
#     C(amp, mu)  = -0.192
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 291.000001
#     reduced chi-square = 41.5714287
#     Akaike info crit   = 39.7073818
#     Bayesian info crit = 40.6151370
# [[Variables]]
#     amp:  53.0060240 +/- 490.476575 (925.32%) (init = 53)
#     mu:  -0.19905435 +/- 38.4732280 (19328.00%) (init = -0.25)
#     std:  0.00786825 +/- 2.23657212 (28425.27%) (init = 0.4930066)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  =  1.000
#     C(amp, std) = -0.140
#     C(mu, std)  = -0.136
