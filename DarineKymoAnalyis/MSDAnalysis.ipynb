# %%
import os
import sys
sys.path.append('../')
import pandas as pd
import numpy as np
import glob
from utils import MSDAnalysis

# %%
CsvDir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/'
Savedir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/Results/'

# %%
nbins = 15

# %%
Raw_path = os.path.join(CsvDir, '*csv')
X = glob.glob(Raw_path)
for CsvFile in X:
   MSDAnalysis(CsvFile, Savedir, nbins)
# Out:
# FileA
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 26
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 550.480414
#     reduced chi-square = 45.8733678
#     Akaike info crit   = 60.0411176
#     Bayesian info crit = 62.1652682
# [[Variables]]
#     amp:  176.439106 +/- 7.35630737 (4.17%) (init = 171)
#     mu:  -0.68791690 +/- 0.11305865 (16.43%) (init = 0.4220963)
#     std:  9.23327905 +/- 0.87916101 (9.52%) (init = 4.686823)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.552
#     C(mu, std)  =  0.272
#     C(amp, mu)  = -0.196
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 3083.00573
#     reduced chi-square = 256.917144
#     Akaike info crit   = 85.8841513
#     Bayesian info crit = 88.0083019
# [[Variables]]
#     amp:  136.654605 +/- 16.5337167 (12.10%) (init = 136)
#     mu:   0.02810109 +/- 0.13572471 (482.99%) (init = 0.4249292)
#     std:  0.92642165 +/- 0.24816014 (26.79%) (init = 2.74314)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.390
#     C(mu, std)  = -0.250
#     C(amp, mu)  =  0.177
# FileB
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 182.949878
#     reduced chi-square = 15.2458232
#     Akaike info crit   = 43.5174304
#     Bayesian info crit = 45.6415810
# [[Variables]]
#     amp:  73.5291860 +/- 3.17869238 (4.32%) (init = 69)
#     mu:  -2.15838539 +/- 0.22097388 (10.24%) (init = 0.242915)
#     std:  39.1875048 +/- 3.91249395 (9.98%) (init = 5.753867)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 299.647160
#     reduced chi-square = 24.9705967
#     Akaike info crit   = 50.9183317
#     Bayesian info crit = 53.0424823
# [[Variables]]
#     amp:  36.6797219 +/- 2.78929182 (7.60%) (init = 43)
#     mu:  -0.28819503 +/- 0.44506805 (154.43%) (init = 0.6072874)
#     std:  50.8062374 +/- 9.46319837 (18.63%) (init = 4.632619)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.592
# FileC
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 35
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 378.940640
#     reduced chi-square = 31.5783866
#     Akaike info crit   = 54.4399405
#     Bayesian info crit = 56.5640911
# [[Variables]]
#     amp:  237.655757 +/- 6.02926959 (2.54%) (init = 234)
#     mu:  -3.70631466 +/- 0.14430684 (3.89%) (init = 0.05277778)
#     std:  19.2294588 +/- 1.14833884 (5.97%) (init = 5.148354)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.403
#     C(mu, std)  = -0.378
#     C(amp, mu)  =  0.291
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 53
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 3165.00135
#     reduced chi-square = 263.750112
#     Akaike info crit   = 86.2778784
#     Bayesian info crit = 88.4020290
# [[Variables]]
#     amp:  140.361065 +/- 16.5276493 (11.78%) (init = 142)
#     mu:  -0.81802711 +/- 0.22189276 (27.13%) (init = 0.05)
#     std:  3.66191540 +/- 0.92926266 (25.38%) (init = 3.854687)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.456
#     C(mu, std)  = -0.157
#     C(amp, mu)  =  0.105
# Dpa_05_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 182.949878
#     reduced chi-square = 15.2458232
#     Akaike info crit   = 43.5174304
#     Bayesian info crit = 45.6415810
# [[Variables]]
#     amp:  73.5291860 +/- 3.17869238 (4.32%) (init = 69)
#     mu:  -2.15838539 +/- 0.22097388 (10.24%) (init = 0.242915)
#     std:  39.1875048 +/- 3.91249395 (9.98%) (init = 5.753867)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 299.647160
#     reduced chi-square = 24.9705967
#     Akaike info crit   = 50.9183317
#     Bayesian info crit = 53.0424823
# [[Variables]]
#     amp:  36.6797219 +/- 2.78929182 (7.60%) (init = 43)
#     mu:  -0.28819503 +/- 0.44506805 (154.43%) (init = 0.6072874)
#     std:  50.8062374 +/- 9.46319837 (18.63%) (init = 4.632619)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.592
# Dpa_04_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 850.342342
#     reduced chi-square = 70.8618618
#     Akaike info crit   = 66.5638323
#     Bayesian info crit = 68.6879829
# [[Variables]]
#     amp:  178.281745 +/- 8.72112105 (4.89%) (init = 177)
#     mu:  -0.68191920 +/- 0.17799308 (26.10%) (init = 0.7212644)
#     std:  13.8804270 +/- 1.48612354 (10.71%) (init = 5.6604)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.476
#     C(mu, std)  =  0.215
#     C(amp, mu)  = -0.148
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 85
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 4201.92948
#     reduced chi-square = 350.160790
#     Akaike info crit   = 90.5287335
#     Bayesian info crit = 92.6528841
# [[Variables]]
#     amp:  81.3547208 +/- 13.9884544 (17.19%) (init = 122)
#     mu:  -0.56591723 +/- 0.52114081 (92.09%) (init = 0.1293103)
#     std:  13.7845875 +/- 5.47194198 (39.70%) (init = 3.706619)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Dpa_10_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 78
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 2228.71044
#     reduced chi-square = 185.725870
#     Akaike info crit   = 81.0169232
#     Bayesian info crit = 83.1410738
# [[Variables]]
#     amp:  82.7375470 +/- 11.9936849 (14.50%) (init = 103)
#     mu:  -1.00845237 +/- 0.34128292 (33.84%) (init = 0.2666667)
#     std:  8.29952451 +/- 2.77706047 (33.46%) (init = 3.2104)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 45
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 2972.69023
#     reduced chi-square = 247.724186
#     Akaike info crit   = 85.3375863
#     Bayesian info crit = 87.4617370
# [[Variables]]
#     amp:  89.9857462 +/- 15.9690890 (17.75%) (init = 90)
#     mu:  -0.06087125 +/- 0.22266318 (365.79%) (init = -0.5444444)
#     std:  0.95485062 +/- 0.37972354 (39.77%) (init = 2.875804)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.327
#     C(mu, std)  =  0.182
#     C(amp, mu)  = -0.130
# Dpa_01_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 41
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 91.8809300
#     reduced chi-square = 7.65674416
#     Akaike info crit   = 33.1866495
#     Bayesian info crit = 35.3108001
# [[Variables]]
#     amp:  17.7099430 +/- 1.63281333 (9.22%) (init = 22)
#     mu:  -0.44509564 +/- 0.53562840 (120.34%) (init = -0.2232143)
#     std:  50.6902334 +/- 10.8261189 (21.36%) (init = 5.396278)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.579
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 49
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 158.847484
#     reduced chi-square = 13.2372904
#     Akaike info crit   = 41.3984148
#     Bayesian info crit = 43.5225654
# [[Variables]]
#     amp:  16.2588824 +/- 2.03348130 (12.51%) (init = 24)
#     mu:   0.46041365 +/- 0.74416924 (161.63%) (init = 0.4910714)
#     std:  53.0906860 +/- 15.8403454 (29.84%) (init = 5.058577)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.587
# Dpa_07_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 35
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 378.940640
#     reduced chi-square = 31.5783866
#     Akaike info crit   = 54.4399405
#     Bayesian info crit = 56.5640911
# [[Variables]]
#     amp:  237.655757 +/- 6.02926959 (2.54%) (init = 234)
#     mu:  -3.70631466 +/- 0.14430684 (3.89%) (init = 0.05277778)
#     std:  19.2294588 +/- 1.14833884 (5.97%) (init = 5.148354)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.403
#     C(mu, std)  = -0.378
#     C(amp, mu)  =  0.291
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 53
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 3165.00135
#     reduced chi-square = 263.750112
#     Akaike info crit   = 86.2778784
#     Bayesian info crit = 88.4020290
# [[Variables]]
#     amp:  140.361065 +/- 16.5276493 (11.78%) (init = 142)
#     mu:  -0.81802711 +/- 0.22189276 (27.13%) (init = 0.05)
#     std:  3.66191540 +/- 0.92926266 (25.38%) (init = 3.854687)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.456
#     C(mu, std)  = -0.157
#     C(amp, mu)  =  0.105
# Dpa_08_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 43
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 286.617589
#     reduced chi-square = 23.8847991
#     Akaike info crit   = 50.2514803
#     Bayesian info crit = 52.3756309
# [[Variables]]
#     amp:  132.788847 +/- 4.76279851 (3.59%) (init = 135)
#     mu:  -2.21150844 +/- 0.15629781 (7.07%) (init = 0.383871)
#     std:  27.4466637 +/- 2.23828208 (8.16%) (init = 5.261951)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.562
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 1561.97134
#     reduced chi-square = 130.164279
#     Akaike info crit   = 75.6848067
#     Bayesian info crit = 77.8089573
# [[Variables]]
#     amp:  60.4048325 +/- 7.40513951 (12.26%) (init = 85)
#     mu:  -1.65647265 +/- 0.53081721 (32.05%) (init = -0.4)
#     std:  28.1329696 +/- 7.96383173 (28.31%) (init = 3.945761)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Dpa_09_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 1613.15961
#     reduced chi-square = 134.429968
#     Akaike info crit   = 76.1684974
#     Bayesian info crit = 78.2926480
# [[Variables]]
#     amp:  96.2221169 +/- 11.6884260 (12.15%) (init = 97)
#     mu:   0.07726095 +/- 0.16430501 (212.66%) (init = -0.06198347)
#     std:  1.64904134 +/- 0.42709056 (25.90%) (init = 2.645806)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.410
#     C(mu, std)  = -0.121
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 1732.87007
#     reduced chi-square = 144.405839
#     Akaike info crit   = 77.2422617
#     Bayesian info crit = 79.3664123
# [[Variables]]
#     amp:  50.4218279 +/- 8.06572252 (16.00%) (init = 73)
#     mu:  -0.29076159 +/- 0.50898414 (175.05%) (init = 0.4256198)
#     std:  15.1895237 +/- 5.61280684 (36.95%) (init = 3.155188)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Dpa_12_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 26
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 108.561376
#     reduced chi-square = 9.04678136
#     Akaike info crit   = 35.6889824
#     Bayesian info crit = 37.8131330
# [[Variables]]
#     amp:  8.51628169 +/- 1.59550149 (18.73%) (init = 12)
#     mu:  -2.76787742 +/- 0.86061053 (31.09%) (init = -2.646154)
#     std:  31.1347165 +/- 14.4328854 (46.36%) (init = 3.780235)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.594
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 72.4230981
#     reduced chi-square = 6.03525817
#     Akaike info crit   = 29.6171262
#     Bayesian info crit = 31.7412768
# [[Variables]]
#     amp:  7.57641618 +/- 1.22497663 (16.17%) (init = 13)
#     mu:  -0.46962025 +/- 0.61067003 (130.03%) (init = -0.09230769)
#     std:  21.5012920 +/- 8.45967698 (39.34%) (init = 3.252091)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.594
# Dpa_06_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 478.909917
#     reduced chi-square = 39.9091597
#     Akaike info crit   = 57.9519347
#     Bayesian info crit = 60.0760853
# [[Variables]]
#     amp:  102.140034 +/- 7.84217870 (7.68%) (init = 98)
#     mu:  -1.44209057 +/- 0.30612974 (21.23%) (init = 1.466667)
#     std:  10.9237135 +/- 2.07309600 (18.98%) (init = 6.823489)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(mu, std)  = -0.577
#     C(amp, std) = -0.571
#     C(amp, mu)  =  0.493
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 35
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 708.258521
#     reduced chi-square = 59.0215434
#     Akaike info crit   = 63.8213845
#     Bayesian info crit = 65.9455351
# [[Variables]]
#     amp:  87.9388744 +/- 7.69958112 (8.76%) (init = 88)
#     mu:  -1.09797830 +/- 0.18437454 (16.79%) (init = 0.1333333)
#     std:  2.07137880 +/- 0.42426049 (20.48%) (init = 3.679372)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.259
# Dpa_03_MSD
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-49d4ae71dcf5> in <module>
#       2 X = glob.glob(Raw_path)
#       3 for CsvFile in X:
# ----> 4    MSDAnalysis(CsvFile, Savedir, nbins)
#       5
#
# ~/Downloads/BioPython/utils.py in MSDAnalysis(CsvFile, savedir, nbins)
#     277
#     278
# --> 279   mean, std = norm.fit(deltaX)
#     280
#     281   counts, bins = np.histogram(deltaX, bins = nbins)
#
# ~/anaconda3/envs/tensorflowGPU/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py in fit(self, data, **kwds)
#     349
#     350         if not np.isfinite(data).all():
# --> 351             raise RuntimeError("The data contains non-finite values.")
#     352
#     353         if floc is None:
#
# RuntimeError: The data contains non-finite values.
