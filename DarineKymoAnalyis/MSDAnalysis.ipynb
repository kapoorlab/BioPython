# %%
import os
import sys
sys.path.append('../')
import pandas as pd
import numpy as np
import glob
from utils import MSDAnalysis

# %%
CsvDir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/'
Savedir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/Results/'

# %%
nbins = 10

# %%
Raw_path = os.path.join(CsvDir, '*csv')
X = glob.glob(Raw_path)
for CsvFile in X:
   MSDAnalysis(CsvFile, Savedir, nbins)
# Out:
# FileA
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 285.847029
#     reduced chi-square = 40.8352898
#     Akaike info crit   = 39.5287171
#     Bayesian info crit = 40.4364724
# [[Variables]]
#     amp:  220.143419 +/- 8.21577360 (3.73%) (init = 207)
#     mu:  -2.23226062 +/- 0.14531694 (6.51%) (init = 0.4220963)
#     std:  14.7915582 +/- 1.34356077 (9.08%) (init = 4.686823)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.632
#     C(mu, std)  = -0.572
#     C(amp, mu)  =  0.483
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 85
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 2293.53404
#     reduced chi-square = 327.647720
#     Akaike info crit   = 60.3526406
#     Bayesian info crit = 61.2603959
# [[Variables]]
#     amp:  108.725639 +/- 16.0623243 (14.77%) (init = 114)
#     mu:  -0.59300175 +/- 0.31180194 (52.58%) (init = 0.4249292)
#     std:  6.69356250 +/- 2.28516855 (34.14%) (init = 2.74314)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# FileB
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 35
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 148.651224
#     reduced chi-square = 21.2358891
#     Akaike info crit   = 32.9901769
#     Bayesian info crit = 33.8979322
# [[Variables]]
#     amp:  104.987578 +/- 4.46759683 (4.26%) (init = 99)
#     mu:  -3.09947627 +/- 0.23017525 (7.43%) (init = 0.242915)
#     std:  43.8712388 +/- 4.31190160 (9.83%) (init = 5.753867)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 42
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 293.192756
#     reduced chi-square = 41.8846794
#     Akaike info crit   = 39.7824517
#     Bayesian info crit = 40.6902070
# [[Variables]]
#     amp:  53.2756846 +/- 4.34762787 (8.16%) (init = 58)
#     mu:  -0.73265870 +/- 0.49871022 (68.07%) (init = 0.6072874)
#     std:  55.1197539 +/- 11.1465050 (20.22%) (init = 4.632619)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.595
# FileC
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 5.14603637
#     reduced chi-square = 0.73514805
#     Akaike info crit   = -0.64358312
#     Bayesian info crit = 0.26417216
# [[Variables]]
#     amp:  264.357417 +/- 1.28011897 (0.48%) (init = 246)
#     mu:  -3.18437778 +/- 0.03325004 (1.04%) (init = 0.05277778)
#     std:  39.3937591 +/- 0.47790344 (1.21%) (init = 5.148354)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.707
#     C(mu, std)  =  0.697
#     C(amp, mu)  = -0.640
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 50
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1429.44709
#     reduced chi-square = 204.206727
#     Akaike info crit   = 55.6245790
#     Bayesian info crit = 56.5323343
# [[Variables]]
#     amp:  158.585260 +/- 14.5585096 (9.18%) (init = 161)
#     mu:  -1.53709960 +/- 0.25726164 (16.74%) (init = 0.05)
#     std:  10.4125657 +/- 2.13527171 (20.51%) (init = 3.854687)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.536
#     C(mu, std)  = -0.116
# Dpa_05_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 35
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 148.651224
#     reduced chi-square = 21.2358891
#     Akaike info crit   = 32.9901769
#     Bayesian info crit = 33.8979322
# [[Variables]]
#     amp:  104.987578 +/- 4.46759683 (4.26%) (init = 99)
#     mu:  -3.09947627 +/- 0.23017525 (7.43%) (init = 0.242915)
#     std:  43.8712388 +/- 4.31190160 (9.83%) (init = 5.753867)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 42
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 293.192756
#     reduced chi-square = 41.8846794
#     Akaike info crit   = 39.7824517
#     Bayesian info crit = 40.6902070
# [[Variables]]
#     amp:  53.2756846 +/- 4.34762787 (8.16%) (init = 58)
#     mu:  -0.73265870 +/- 0.49871022 (68.07%) (init = 0.6072874)
#     std:  55.1197539 +/- 11.1465050 (20.22%) (init = 4.632619)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.595
# Dpa_04_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 32
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 245.973661
#     reduced chi-square = 35.1390944
#     Akaike info crit   = 38.0263937
#     Bayesian info crit = 38.9341490
# [[Variables]]
#     amp:  215.006462 +/- 7.34471095 (3.42%) (init = 202)
#     mu:  -1.50010608 +/- 0.16251894 (10.83%) (init = 0.7212644)
#     std:  25.7121676 +/- 2.10989831 (8.21%) (init = 5.6604)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.623
#     C(mu, std)  =  0.503
#     C(amp, mu)  = -0.410
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 54
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 918.010029
#     reduced chi-square = 131.144290
#     Akaike info crit   = 51.1962322
#     Bayesian info crit = 52.1039875
# [[Variables]]
#     amp:  112.804477 +/- 9.96943750 (8.84%) (init = 122)
#     mu:  -0.41224247 +/- 0.29618241 (71.85%) (init = 0.1293103)
#     std:  16.8322553 +/- 3.43283198 (20.39%) (init = 3.706619)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Dpa_10_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 140.981643
#     reduced chi-square = 20.1402346
#     Akaike info crit   = 32.4604459
#     Bayesian info crit = 33.3682012
# [[Variables]]
#     amp:  99.0548145 +/- 4.03645811 (4.07%) (init = 103)
#     mu:  -0.78415796 +/- 0.13765282 (17.55%) (init = 0.2666667)
#     std:  17.0449605 +/- 1.60005644 (9.39%) (init = 3.2104)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.575
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 41
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 998.341518
#     reduced chi-square = 142.620217
#     Akaike info crit   = 52.0351033
#     Bayesian info crit = 52.9428585
# [[Variables]]
#     amp:  75.2332009 +/- 9.36316717 (12.45%) (init = 91)
#     mu:  -1.25183360 +/- 0.35686942 (28.51%) (init = -0.5444444)
#     std:  12.3519875 +/- 3.56400172 (28.85%) (init = 2.875804)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.579
# Dpa_01_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 82
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 176.343276
#     reduced chi-square = 25.1918966
#     Akaike info crit   = 34.6984743
#     Bayesian info crit = 35.6062296
# [[Variables]]
#     amp:  28.4795453 +/- 3.87167601 (13.59%) (init = 31)
#     mu:  -0.57887923 +/- 0.69229219 (119.59%) (init = -0.2232143)
#     std:  38.9173324 +/- 12.2232083 (31.41%) (init = 5.396278)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 57
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 123.530184
#     reduced chi-square = 17.6471692
#     Akaike info crit   = 31.1390044
#     Bayesian info crit = 32.0467597
# [[Variables]]
#     amp:  26.2384726 +/- 3.01743455 (11.50%) (init = 32)
#     mu:   0.19304559 +/- 0.61517191 (318.67%) (init = 0.4910714)
#     std:  43.0344221 +/- 11.6104833 (26.98%) (init = 5.058577)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.583
# Dpa_07_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 5.14603637
#     reduced chi-square = 0.73514805
#     Akaike info crit   = -0.64358312
#     Bayesian info crit = 0.26417216
# [[Variables]]
#     amp:  264.357417 +/- 1.28011897 (0.48%) (init = 246)
#     mu:  -3.18437778 +/- 0.03325004 (1.04%) (init = 0.05277778)
#     std:  39.3937591 +/- 0.47790344 (1.21%) (init = 5.148354)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.707
#     C(mu, std)  =  0.697
#     C(amp, mu)  = -0.640
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 50
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1429.44709
#     reduced chi-square = 204.206727
#     Akaike info crit   = 55.6245790
#     Bayesian info crit = 56.5323343
# [[Variables]]
#     amp:  158.585260 +/- 14.5585096 (9.18%) (init = 161)
#     mu:  -1.53709960 +/- 0.25726164 (16.74%) (init = 0.05)
#     std:  10.4125657 +/- 2.13527171 (20.51%) (init = 3.854687)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.536
#     C(mu, std)  = -0.116
# Dpa_08_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 44
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 44.1583144
#     reduced chi-square = 6.30833063
#     Akaike info crit   = 20.8519614
#     Bayesian info crit = 21.7597167
# [[Variables]]
#     amp:  175.618449 +/- 2.78247919 (1.58%) (init = 166)
#     mu:  -3.05555099 +/- 0.08521821 (2.79%) (init = 0.383871)
#     std:  39.2845126 +/- 1.44523113 (3.68%) (init = 5.261951)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.580
#     C(mu, std)  =  0.277
#     C(amp, mu)  = -0.203
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 30
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 51.0202290
#     reduced chi-square = 7.28860414
#     Akaike info crit   = 22.2963711
#     Bayesian info crit = 23.2041264
# [[Variables]]
#     amp:  87.5886261 +/- 2.10130671 (2.40%) (init = 85)
#     mu:  -1.63347456 +/- 0.10836047 (6.63%) (init = -0.4)
#     std:  30.6037859 +/- 1.69571848 (5.54%) (init = 3.945761)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Dpa_09_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 30
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 93.2574117
#     reduced chi-square = 13.3224874
#     Akaike info crit   = 28.3277844
#     Bayesian info crit = 29.2355397
# [[Variables]]
#     amp:  85.1267833 +/- 3.22982275 (3.79%) (init = 85)
#     mu:  -0.90737659 +/- 0.09944332 (10.96%) (init = -0.06198347)
#     std:  10.3039832 +/- 0.90295686 (8.76%) (init = 2.645806)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 49
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1540.57294
#     reduced chi-square = 220.081849
#     Akaike info crit   = 56.3732457
#     Bayesian info crit = 57.2810010
# [[Variables]]
#     amp:  79.4890931 +/- 12.7090921 (15.99%) (init = 96)
#     mu:  -0.96431829 +/- 0.46844597 (48.58%) (init = 0.4256198)
#     std:  12.8820590 +/- 4.75874939 (36.94%) (init = 3.155188)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Dpa_12_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 20.0309487
#     reduced chi-square = 2.86156410
#     Akaike info crit   = 12.9469342
#     Bayesian info crit = 13.8546895
# [[Variables]]
#     amp:  14.0164979 +/- 1.15804902 (8.26%) (init = 14)
#     mu:  -3.42377173 +/- 0.33154850 (9.68%) (init = -2.646154)
#     std:  24.2029624 +/- 4.72524601 (19.52%) (init = 3.780235)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.585
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 49
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 215.212953
#     reduced chi-square = 30.7447076
#     Akaike info crit   = 36.6904292
#     Bayesian info crit = 37.5981845
# [[Variables]]
#     amp:  10.6325329 +/- 3.27615535 (30.81%) (init = 19)
#     mu:  -0.34872523 +/- 1.27566356 (365.81%) (init = -0.09230769)
#     std:  25.6573452 +/- 20.0626063 (78.19%) (init = 3.252091)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.604
# Dpa_06_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 36
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 103.006187
#     reduced chi-square = 14.7151695
#     Akaike info crit   = 29.3220396
#     Bayesian info crit = 30.2297949
# [[Variables]]
#     amp:  113.052719 +/- 3.85348490 (3.41%) (init = 113)
#     mu:  -0.17650312 +/- 0.23284878 (131.92%) (init = 1.466667)
#     std:  26.5599986 +/- 2.03223926 (7.65%) (init = 6.823489)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.299
#     C(mu, std)  =  0.105
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 30
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1029.21435
#     reduced chi-square = 147.030621
#     Akaike info crit   = 52.3396593
#     Bayesian info crit = 53.2474146
# [[Variables]]
#     amp:  105.752695 +/- 13.0297313 (12.32%) (init = 105)
#     mu:  -1.83728453 +/- 0.47189056 (25.68%) (init = 0.1333333)
#     std:  3.58178565 +/- 1.28328194 (35.83%) (init = 3.679372)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(mu, std)  = -0.364
#     C(amp, mu)  =  0.339
#     C(amp, std) = -0.286
# Dpa_03_MSD
# DeltaX [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 30
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 88.6861885
#     reduced chi-square = 12.6694555
#     Akaike info crit   = 27.8251907
#     Bayesian info crit = 28.7329460
# [[Variables]]
#     amp:  40.1204200 +/- 3.63345516 (9.06%) (init = 40)
#     mu:  -2.15245938 +/- 0.56041924 (26.04%) (init = 2.347222)
#     std:  22.7275071 +/- 4.65612405 (20.49%) (init = 7.958503)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.332
#     C(mu, std)  = -0.216
#     C(amp, mu)  =  0.156
# DeltaY [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 106.125133
#     reduced chi-square = 15.1607333
#     Akaike info crit   = 29.6203380
#     Bayesian info crit = 30.5280933
# [[Variables]]
#     amp:  30.8063215 +/- 4.26724809 (13.85%) (init = 30)
#     mu:  -0.74952168 +/- 0.20025834 (26.72%) (init = -0.6527778)
#     std:  1.98148090 +/- 0.62580781 (31.58%) (init = 3.055777)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.504
#     C(mu, std)  = -0.369
#     C(amp, mu)  =  0.273
