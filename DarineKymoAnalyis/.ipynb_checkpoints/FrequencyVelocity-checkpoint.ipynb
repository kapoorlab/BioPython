# %%
import sys
sys.path.append("../")
import numpy as np
from scipy.fftpack import fftfreq
import os
import glob
import csv
from utils import show_peak, FFTStrip, doubleplot, doFilterFFT, VelocityStrip, watershed_image_hough
import pandas as pd
from tifffile import imread
from scipy.fftpack import fft
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
from skimage.morphology import remove_small_objects, binary_erosion
from bokeh.plotting import figure, output_file, show
from bokeh.io import export_png, output_notebook
from scipy.signal import find_peaks
from skimage import data, io
from bokeh.models import Label
from skimage.filters import threshold_otsu, threshold_mean
from skimage.filters import roberts, sobel, scharr, prewitt, gaussian
try:
    from pathlib import Path
    Path().expanduser()
except (ImportError, AttributeError):
        from pathlib2 import Path

try:
        import tempfile
        tempfile.TemporaryDirectory
except (ImportError, AttributeError):
       from backports import tempfile

# %%
sourcedirKymo = '/Users/aimachine/DarineKymo/'
savedir = sourcedirKymo + 'Results/'
Time_unit = 10
Xcalibration = 0.034
blocksize = 50
ignorelast = 5

# %%
Raw_path = os.path.join(sourcedirKymo, '*tif')
X = glob.glob(Raw_path)
Path(savedir).mkdir(exist_ok = True)
AverageVelocity = []
Block = []
AverageFrequ = []
Frequency = []
ImageName = []
AnteriorList = []
PosteriorList = []
for fname in X:
    image = imread(fname)
    #image = np.swapaxes(image,0,1)
    #X axis should be time
  
    Name = os.path.basename(os.path.splitext(fname)[0])

    #Get simple velocity

    ImageName.append(Name)
    BlockVelocity = VelocityStrip(image,blocksize,Xcalibration)
    IndexList = []
    VelocityList = []
    for i in range(0, len(BlockVelocity) - ignorelast):
        
        index, velocity = BlockVelocity[i]
        IndexList.append(index)
        VelocityList.append(velocity)
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    ax = axes.ravel()
    ax[0].imshow(image)
    ax[0].set_xlabel('Time')
    ax[0].set_ylabel('BlockID')
    ax[1].plot(IndexList, VelocityList, 'ro')
    ax[1].plot(IndexList, VelocityList, 'g')
    ax[1].set_title('Time Averaged Block Variance')
    ax[1].set_xlabel('BlockID')
    ax[1].set_ylabel('Velocity')
    plt.show()
    df = pd.DataFrame(list(zip(VelocityList,IndexList)), columns =['Velocity', 'BlockIndex'])
    df.to_csv(savedir + Name + "SimpleVelocity"  '.csv', index = False)  
         
    Anterior =    VelocityList[:len(VelocityList)//2]
    Posterior = VelocityList[len(VelocityList)//2:]
    AnteriorList.append(np.mean(Anterior))
    PosteriorList.append(np.mean(Posterior))
    print('Anterior Part : ', np.mean(Anterior), 'Posterior Part :', np.mean(Posterior))
df = pd.DataFrame(list(zip(AnteriorList,PosteriorList)),index = ImageName, columns =['Anterior Part', 'Posterior Part'])
df.to_csv(savedir + Name + "AnteriorPosterior"  '.csv', index = False)   
df
# Out:
# Anterior Part :  153.7956 Posterior Part : 141.4641
# Anterior Part :  96.594666 Posterior Part : 62.352917
# Anterior Part :  147.91153 Posterior Part : 152.36418
# Anterior Part :  185.52116 Posterior Part : 167.48466
# Anterior Part :  148.21625 Posterior Part : 178.54936
# Anterior Part :  188.73439 Posterior Part : 123.36934
# Anterior Part :  155.69977 Posterior Part : 149.44942
# Anterior Part :  102.58869 Posterior Part : 96.092705
# Anterior Part :  170.27159 Posterior Part : 188.3735
# Anterior Part :  117.73273 Posterior Part : 115.84389
#                                                     Anterior Part  \
# DistanceMethodCurvature_Dpachys6_RAWTrackID1           153.795593
# DistanceMethodCurvature_Dpa_05_RAWAdjustedTrackID1      96.594666
# DistanceMethodCurvature_Dpachys_13-adjustedTrac...     147.911530
# DistanceMethodCurvature_Dpachys_08-adjustedTrac...     185.521164
# DistanceMethodCurvature_Dpachys_12_tempTrackID1        148.216248
# DistanceMethodCurvature_Dpachys_15-adjustedTrac...     188.734390
# DistanceMethodCurvature_Dpachys_10-adjustedTrac...     155.699768
# DistanceMethodCurvature_registered embryoTrackID1      102.588692
# DistanceMethodCurvature_Dpachys_14-adjustedTrac...     170.271591
# DistanceMethodCurvature_Dpachys_11-adjustedTrac...     117.732727
#
#                                                     Posterior Part
# DistanceMethodCurvature_Dpachys6_RAWTrackID1            141.464096
# DistanceMethodCurvature_Dpa_05_RAWAdjustedTrackID1       62.352917
# DistanceMethodCurvature_Dpachys_13-adjustedTrac...      152.364182
# DistanceMethodCurvature_Dpachys_08-adjustedTrac...      167.484665
# DistanceMethodCurvature_Dpachys_12_tempTrackID1         178.549362
# DistanceMethodCurvature_Dpachys_15-adjustedTrac...      123.369339
# DistanceMethodCurvature_Dpachys_10-adjustedTrac...      149.449417
# DistanceMethodCurvature_registered embryoTrackID1        96.092705
# DistanceMethodCurvature_Dpachys_14-adjustedTrac...      188.373505
# DistanceMethodCurvature_Dpachys_11-adjustedTrac...      115.843887
