# %%
import csv
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
CsvFile = '/Users/aimachine/DarineCSV/NT.csv'
Savedir = '/Users/aimachine/DarineCSV/'
Path(Savedir).mkdir(exist_ok=True)

# %%
dataset = pd.read_csv(CsvFile)
df = pd.DataFrame(dataset)
df
# Out:
#    TIME  DPA02  DPA04  DPA10  DPA24  DPA45  DPA06  DPA11  DPA16  DPA35
# 0    35  58.06  51.23  57.28  51.19  51.47  21.66  24.90  22.33  22.73
# 1    30  56.35  48.28  58.44  50.33  48.09  16.38  28.15  26.33  20.30
# 2    25  58.28  46.18  56.44  51.12  44.65  18.71  25.93  29.58  26.74
# 3    20  55.77  48.42  45.05  51.36  53.33  25.82  28.57  40.53  32.33
# 4    15  46.13  46.18  43.63  48.80  48.86  40.40  42.18  44.59  48.75
# 5    10  42.50  47.27  46.62  49.24  46.77  45.99  46.08  50.00  50.45

# %%
time = dataset["TIME"]
time = np.asarray(time)

# %%
DPA2 = dataset["DPA02"]
DPA2 = np.asarray(DPA2)

VelDPA2 = diff(DPA2)/diff(time)

plt.plot(time[1:],VelDPA2)
plt.title("DPA2 velocity")
plt.show()

# %%
DPA4 = dataset["DPA04"]
DPA4 = np.asarray(DPA4)

VelDPA4 = diff(DPA4)/diff(time)

plt.plot(time[1:],VelDPA4)
plt.title("DPA4 velocity")
plt.show()

# %%
DPA10 = dataset["DPA10"]
DPA10 = np.asarray(DPA10)

VelDPA10 = diff(DPA10)/diff(time)

plt.plot(time[1:],VelDPA10)
plt.title("DPA10 velocity")
plt.show()

# %%
DPA24 = dataset["DPA24"]
DPA24 = np.asarray(DPA24)

VelDPA24 = diff(DPA24)/diff(time)

plt.plot(time[1:],VelDPA24)
plt.title("DPA24 velocity")
plt.show()

# %%
DPA45 = dataset["DPA45"]
DPA45 = np.asarray(DPA45)

VelDPA45 = diff(DPA45)/diff(time)

plt.plot(time[1:],VelDPA45)
plt.title("DPA45 velocity")
plt.show()

# %%
DPA06 = dataset["DPA06"]
DPA06 = np.asarray(DPA06)

VelDPA06 = diff(DPA06)/diff(time)

plt.plot(time[1:],VelDPA06)
plt.title("DPA06 velocity")
plt.show()

# %%
DPA11 = dataset["DPA11"]
DPA11 = np.asarray(DPA11)

VelDPA11 = diff(DPA11)/diff(time)

plt.plot(time[1:],VelDPA11)
plt.title("DPA11 velocity")
plt.show()

# %%
DPA16 = dataset["DPA16"]
DPA16 = np.asarray(DPA16)

VelDPA16 = diff(DPA16)/diff(time)

plt.plot(time[1:],VelDPA16)
plt.title("DPA16 velocity")
plt.show()

# %%
DPA35 = dataset["DPA35"]
DPA35 = np.asarray(DPA35)

VelDPA35 = diff(DPA35)/diff(time)

plt.plot(time[1:],VelDPA35)
plt.title("DPA35 velocity")
plt.show()
