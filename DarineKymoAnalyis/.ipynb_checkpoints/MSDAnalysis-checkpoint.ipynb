# %%
import os
import sys
sys.path.append('../')
import pandas as pd
import numpy as np
import glob
from utils import MSDAnalysis

# %%
CsvDir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/'
Savedir = '/home/kapoorlab/Downloads/Darine/Nucleus_tracking/Results/'

# %%
nbins = 20

# %%
Raw_path = os.path.join(CsvDir, '*csv')
X = glob.glob(Raw_path)
for CsvFile in X:
   MSDAnalysis(CsvFile, Savedir, nbins)
# Out:
# FileA
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 39
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 438.460148
#     reduced chi-square = 25.7917734
#     Akaike info crit   = 67.7507330
#     Bayesian info crit = 70.7379299
# [[Variables]]
#     amp:  77.6991657 +/- 3.50546275 (4.51%) (init = 77)
#     mu:   0.07516503 +/- 0.00548296 (7.29%) (init = 0.1385297)
#     std:  0.01481680 +/- 0.00211438 (14.27%) (init = 0.1240673)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.591
#     C(mu, std)  = -0.442
#     C(amp, mu)  =  0.170
# FileB
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 177.168708
#     reduced chi-square = 10.4216887
#     Akaike info crit   = 49.6274032
#     Bayesian info crit = 52.6146000
# [[Variables]]
#     amp:  50.4885360 +/- 2.19291060 (4.34%) (init = 56)
#     mu:   0.13457249 +/- 0.00601606 (4.47%) (init = 0.2093725)
#     std:  0.02566307 +/- 0.00303759 (11.84%) (init = 0.1407761)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.603
#     C(mu, std)  = -0.232
#     C(amp, mu)  =  0.101
# FileC
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 178
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 622.842126
#     reduced chi-square = 36.6377721
#     Akaike info crit   = 74.7712161
#     Bayesian info crit = 77.7584129
# [[Variables]]
#     amp:  2755.08763 +/- 14580.3548 (529.22%) (init = 138)
#     mu:  -1.13515932 +/- 1.79395729 (158.04%) (init = 0.1454889)
#     std:  0.42550796 +/- 0.60456639 (142.08%) (init = 0.1643541)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -0.999
#     C(mu, std)  = -0.999
#     C(amp, std) =  0.995
# Dpa_05_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 177.168708
#     reduced chi-square = 10.4216887
#     Akaike info crit   = 49.6274032
#     Bayesian info crit = 52.6146000
# [[Variables]]
#     amp:  50.4885360 +/- 2.19291060 (4.34%) (init = 56)
#     mu:   0.13457249 +/- 0.00601606 (4.47%) (init = 0.2093725)
#     std:  0.02566307 +/- 0.00303759 (11.84%) (init = 0.1407761)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.603
#     C(mu, std)  = -0.232
#     C(amp, mu)  =  0.101
# Dpa_04_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 49
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 171.583473
#     reduced chi-square = 10.0931455
#     Akaike info crit   = 48.9867520
#     Bayesian info crit = 51.9739488
# [[Variables]]
#     amp:  110.821667 +/- 2.54823180 (2.30%) (init = 105)
#     mu:   0.07310737 +/- 0.00456855 (6.25%) (init = 0.1651092)
#     std:  0.02857307 +/- 0.00237799 (8.32%) (init = 0.1627459)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(mu, std)  = -0.590
#     C(amp, std) = -0.566
#     C(amp, mu)  =  0.206
# Dpa_10_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 30
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 479.532942
#     reduced chi-square = 28.2078201
#     Akaike info crit   = 69.5416064
#     Bayesian info crit = 72.5288032
# [[Variables]]
#     amp:  43.6026610 +/- 3.14269838 (7.21%) (init = 50)
#     mu:   0.09369522 +/- 0.00629444 (6.72%) (init = 0.1257444)
#     std:  0.01040999 +/- 0.00200886 (19.30%) (init = 0.07826464)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.602
#     C(mu, std)  = -0.207
# Dpa_01_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 60.0862011
#     reduced chi-square = 3.53448242
#     Akaike info crit   = 28.0009588
#     Bayesian info crit = 30.9881557
# [[Variables]]
#     amp:  11.9431599 +/- 0.92738029 (7.76%) (init = 14)
#     mu:   0.17432455 +/- 0.00948344 (5.44%) (init = 0.2228482)
#     std:  0.02197135 +/- 0.00422437 (19.23%) (init = 0.1264809)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.594
# Dpa_07_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 178
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 622.842126
#     reduced chi-square = 36.6377721
#     Akaike info crit   = 74.7712161
#     Bayesian info crit = 77.7584129
# [[Variables]]
#     amp:  2755.08763 +/- 14580.3548 (529.22%) (init = 138)
#     mu:  -1.13515932 +/- 1.79395729 (158.04%) (init = 0.1454889)
#     std:  0.42550796 +/- 0.60456639 (142.08%) (init = 0.1643541)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -0.999
#     C(mu, std)  = -0.999
#     C(amp, std) =  0.995
# Dpa_08_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 300.803065
#     reduced chi-square = 17.6942979
#     Akaike info crit   = 60.2144701
#     Bayesian info crit = 63.2016670
# [[Variables]]
#     amp:  86.8565065 +/- 3.31355668 (3.81%) (init = 88)
#     mu:   0.09338149 +/- 0.00506033 (5.42%) (init = 0.1734581)
#     std:  0.02064104 +/- 0.00233370 (11.31%) (init = 0.1424279)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.605
#     C(mu, std)  = -0.353
#     C(amp, mu)  =  0.150
# Dpa_09_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 257.262506
#     reduced chi-square = 15.1330886
#     Akaike info crit   = 57.0872943
#     Bayesian info crit = 60.0744911
# [[Variables]]
#     amp:  48.0787720 +/- 2.59451746 (5.40%) (init = 52)
#     mu:   0.08678767 +/- 0.00380502 (4.38%) (init = 0.1176736)
#     std:  0.00723310 +/- 9.8660e-04 (13.64%) (init = 0.07800618)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.598
#     C(mu, std)  = -0.119
# Dpa_12_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 35
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 145.263096
#     reduced chi-square = 8.54488798
#     Akaike info crit   = 45.6562856
#     Bayesian info crit = 48.6434824
# [[Variables]]
#     amp:  7.84739024 +/- 1.51493919 (19.31%) (init = 16)
#     mu:   0.14689486 +/- 0.01721753 (11.72%) (init = 0.1700615)
#     std:  0.01191628 +/- 0.00549251 (46.09%) (init = 0.08915171)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.587
# Dpa_06_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 162.547243
#     reduced chi-square = 9.56160250
#     Akaike info crit   = 47.9047282
#     Bayesian info crit = 50.8919250
# [[Variables]]
#     amp:  34.1951868 +/- 2.76112963 (8.07%) (init = 37)
#     mu:  -9.4754e-04 +/- 0.54020628 (57011.35%) (init = 1.9137)
#     std:  8.24251211 +/- 2.88583171 (35.01%) (init = 1.88038)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(mu, std)  = -0.920
#     C(amp, mu)  = -0.728
#     C(amp, std) =  0.525
# Dpa_03_MSD
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 8000
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 93.7341710
#     reduced chi-square = 5.51377477
#     Akaike info crit   = 36.8946107
#     Bayesian info crit = 39.8818075
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  1.6518e+24 (init = 20)
#     mu:  -3.87221745 (init = 0.04275342)
#     std:  0.28356554 (init = 0.04825497)
