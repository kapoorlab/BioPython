# %%
import sys
sys.path.append("../")
import numpy as np
import os
import glob
import cv2
import csv
from scipy.signal import find_peaks
from utils import Tsurff, tripleplot
import pandas as pd
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
from pathlib import Path
import napari
from numpy import diff

# %%
Embryo = '/Users/aimachine/Dpachys_10/Dpachys_control.tif'
EmbryoSeg = '/Users/aimachine/Dpachys_10/SegDpachys_control.tif'
savedir = '/Users/aimachine/Dpachys_10/Results/'
Path(savedir).mkdir(exist_ok = True)
Xcalibration = 0.034
Timeunit = 10
theta = 30

# %%
ListMaps, Clock = Tsurff(Embryo,EmbryoSeg, theta)
# Out:
# 100%|██████████| 370/370 [01:00<00:00,  6.08it/s]

# %%
with napari.gui_qt():
              viewer = napari.view_image(imread(Embryo), name='TSURFF')
              viewer.add_labels(Clock)

# %%
PosteriorAngles = [0,90,120 ]
AnteriorAngles = [180, 210, 240, 330]

# %%
for i in range(0, len(ListMaps)):
    
    AngleHashmap = ListMaps[i]
    for (angle,timeddistance) in AngleHashmap.items():
        for i in range(0, len(PosteriorAngles)):
                
                if angle == str(PosteriorAngles[i]):
                        deformation = diff(timeddistance) * Xcalibration/Timeunit
                        plt.plot(deformation)
                        plt.title( 'Angle = ' + str(angle))
                        plt.show()
                        print('Posterior Deformation:', 'Mean = ',np.mean(deformation), 'Standard Deviation = ', np.std(deformation))
# Out:
# Posterior Deformation: Mean =  -0.00010477772782882363 Standard Deviation =  0.004708863624167844
# Posterior Deformation: Mean =  -8.375420077106416e-05 Standard Deviation =  0.006442782225669974
# Posterior Deformation: Mean =  -4.706910838431527e-05 Standard Deviation =  0.007596209683353013

# %%
for i in range(0, len(ListMaps)):
    
    AngleHashmap = ListMaps[i]
    for (angle,timeddistance) in AngleHashmap.items():
        for i in range(0, len(AnteriorAngles)):
                
                if angle == str(AnteriorAngles[i]):
                        deformation = diff(timeddistance) * Xcalibration/Timeunit
                        plt.plot(deformation)
                        plt.title( 'Angle = ' + str(angle))
                        plt.show()
                        print('Anterior Deformation:', 'Mean = ',np.mean(deformation), 'Standard Deviation = ', np.std(deformation))
# Out:
# Anterior Deformation: Mean =  9.403204411411375e-05 Standard Deviation =  0.021833965332497728
# Anterior Deformation: Mean =  -0.00026146549544341416 Standard Deviation =  0.019538246396263417
# Anterior Deformation: Mean =  -0.00011158173955096696 Standard Deviation =  0.016442329370422806
# Anterior Deformation: Mean =  9.711111308891769e-05 Standard Deviation =  0.013036483006599925
