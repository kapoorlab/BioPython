# %%
import sys
sys.path.append("../")
import numpy as np
import os
import glob
import cv2
import csv
from scipy.signal import find_peaks
from utils import Tsurff, tripleplot
import pandas as pd
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
from pathlib import Path
import napari
from numpy import diff

# %%
Embryo = '/Users/aimachine/Dpachys_10/Dpachys_control.tif'
EmbryoSeg = '/Users/aimachine/Dpachys_10/SegDpachys_control.tif'
savedir = '/Users/aimachine/Dpachys_10/Results/'
Path(savedir).mkdir(exist_ok = True)
Xcalibration = 0.034
Timeunit = 10
theta = 30

# %%
ListMaps, Clock = Tsurff(Embryo,EmbryoSeg, theta)
# Out:
# 100%|██████████| 370/370 [01:00<00:00,  6.08it/s]

# %%
with napari.gui_qt():
              viewer = napari.view_image(imread(Embryo), name='TSURFF')
              viewer.add_labels(Clock)

# %%
PosteriorAngles = [0, 30, 60, 90]
AnteriorAngles = [120, 150, 180, 330]

# %%
for i in range(0, len(ListMaps)):
    
    AngleHashmap = ListMaps[i]
    for (angle,timeddistance) in AngleHashmap.items():
        
        deformation = diff(timeddistance) * Xcalibration/Timeunit
        plt.plot(deformation)
        plt.title( 'Angle = ' + str(angle))
        plt.show()
        print('Deformation:', 'Mean = ',np.mean(deformation), 'Standard Deviation = ', np.std(deformation))
# Out:
# Deformation: Mean =  -0.00010477772782882363 Standard Deviation =  0.004708863624167844
# Deformation: Mean =  -0.0001474598809291341 Standard Deviation =  0.005454618089516368
# Deformation: Mean =  -0.00010488719653731474 Standard Deviation =  0.005939387565729084
# Deformation: Mean =  -8.375420077106416e-05 Standard Deviation =  0.006442782225669974
# Deformation: Mean =  -4.706910838431527e-05 Standard Deviation =  0.007596209683353013
# Deformation: Mean =  5.472943645893684e-05 Standard Deviation =  0.007850034896771791
# Deformation: Mean =  9.403204411411375e-05 Standard Deviation =  0.021833965332497728
# Deformation: Mean =  -0.00026146549544341416 Standard Deviation =  0.019538246396263417
# Deformation: Mean =  -0.00011158173955096696 Standard Deviation =  0.016442329370422806
# Deformation: Mean =  -4.227582235313429e-05 Standard Deviation =  0.025842754403525698
# Deformation: Mean =  0.00023958414241363467 Standard Deviation =  0.0454472165673373
# Deformation: Mean =  9.711111308891769e-05 Standard Deviation =  0.013036483006599925
