# %%
import os
import glob
from tifffile import imread
import matplotlib.pyplot as plt
from pathlib import Path
import h5py

# %%
resultsdir = 'C:/Users/rando/Downloads/big_stitcher_project/save_results/'
Path(resultsdir).mkdir(exist_ok = True)
filename = "C:/Users/rando/Downloads/big_stitcher_project/dataset.h5"

with h5py.File(filename, 'r') as fd:
    print(fd.keys(),fd['/s00/resolutions'][...])
    img = fd['/t00000/s00/0/cells'][...]

plt.imshow(img.max(axis=0))
# Out:
# <KeysViewHDF5 ['__DATA_TYPES__', 's00', 's01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 't00000']> [[1. 1. 1.]
#  [2. 2. 1.]
#  [4. 4. 2.]
#  [8. 8. 4.]]
